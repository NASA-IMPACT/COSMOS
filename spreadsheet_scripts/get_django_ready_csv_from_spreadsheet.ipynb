# %%
import pandas as pd
import json

# %%
df = pd.read_excel('sheet.xlsx')

# %%
df
# Out:
#     Collection Title Migrated?             Name of Resource  \
# 0                NaN       NaN                NAVO Registry
# 1                NaN       NaN        Coordinate Calculator
# 2                NaN       NaN        Extinction Calculator
# 3                NaN       NaN          Velocity Calculator
# 4                NaN       NaN  High Level Science Products
# ..               ...       ...                          ...
# 276              NaN       NaN      PDS Subset Tool Website
# 277              NaN       NaN     PDS Users Guides Website
# 278              NaN       NaN       PDS USGS Pilot Website
# 279              NaN       NaN      PDS Web Chronos Website
# 280              NaN       NaN             TASKBOOK Website
#
#          Sinequa Config Guess Sinequa Config Actual Connector Type Assignee  \
# 0                         NaN                   NaN            NaN      NaN
# 1                         NaN                   NaN            NaN      NaN
# 2                         NaN                   NaN            NaN      NaN
# 3                         NaN                   NaN            NaN      NaN
# 4                         NaN                   NaN            NaN      NaN
# ..                        ...                   ...            ...      ...
# 276   PDS_Subset_Tool_Website                   NaN            NaN      NaN
# 277  PDS_Users_Guides_Website                   NaN            NaN      NaN
# 278    PDS_USGS_Pilot_Website                   NaN            NaN      NaN
# 279   PDS_Web_Chronos_Website                   NaN            NaN      NaN
# 280          TASKBOOK_Website                   NaN            NaN      NaN
#
#                                           URL_original  \
# 0                   Use custom connector built by team
# 1    http://ned.ipac.caltech.edu/coordinate_calculator
# 2    http://ned.ipac.caltech.edu/extinction_calculator
# 3      http://ned.ipac.caltech.edu/velocity_calculator
# 4                      https://archive.stsci.edu/hlsp/
# ..                                                 ...
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
#
#                                            URL_sinequa  turned_on  ...  \
# 0                                                  NaN        NaN  ...
# 1                                                  NaN        NaN  ...
# 2                                                  NaN        NaN  ...
# 3                                                  NaN        NaN  ...
# 4                                                  NaN        NaN  ...
# ..                                                 ...        ...  ...
# 276  https://naif.jpl.nasa.gov/cgi-bin/subsetds.pl?...        0.0  ...
# 277         https://pds-imaging.jpl.nasa.gov/software/        1.0  ...
# 278                         https://pilot.wr.usgs.gov/        1.0  ...
# 279  https://naif.jpl.nasa.gov/cgi-bin/chronos.pl?s...        0.0  ...
# 280                                                NaN        0.0  ...
#
#     UrlStayInside                                    UrlLinkExcluded  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# ..            ...                                                ...
# 276           1.0                                                NaN
# 277           1.0                                                NaN
# 278           1.0                                                NaN
# 279           1.0                                                NaN
# 280           1.0  ['http://www.ncbi.nlm.nih.gov/*', 'https://tas...
#
#                                    UrlDownloadExcluded  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280  ['http://www.ncbi.nlm.nih.gov/*', 'https://tas...
#
#                                      UrlFollowExcluded UrlIndexExcluded  \
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 276                                                NaN              NaN
# 277                                                NaN              NaN
# 278                                                NaN              NaN
# 279                                                NaN              NaN
# 280  ['http://www.ncbi.nlm.nih.gov/*', 'https://tas...              NaN
#
#                                       UrlIndexIncluded IncludedExtensions  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 276  https://naif.jpl.nasa.gov/cgi-bin/subsetds.pl?...           htm;html
# 277                                                NaN           htm;html
# 278                         https://pilot.wr.usgs.gov/           htm;html
# 279  https://naif.jpl.nasa.gov/cgi-bin/chronos.pl?s...           htm;html
# 280  https://taskbook.nasaprs.com/tbp/index.cfm?act...                NaN
#
#     ExcludedExtensions ExcludedFilenames Cleaned
# 0                  NaN               NaN     NaN
# 1                  NaN               NaN     NaN
# 2                  NaN               NaN     NaN
# 3                  NaN               NaN     NaN
# 4                  NaN               NaN     NaN
# ..                 ...               ...     ...
# 276                NaN               NaN     NaN
# 277                NaN               NaN     NaN
# 278                NaN               NaN     NaN
# 279                NaN               NaN     NaN
# 280                NaN               NaN     NaN
#
# [281 rows x 57 columns]

# %%
columns_to_bring_in = {
    'Name of Resource': 'name',
    'Sinequa Config Guess': 'config_folder',
    'URL_original': 'url',
    'turned_on': 'turned_on',
    'Division': 'division',
    'Source': 'source',
    'TreeRoot': 'tree_root',
    'Frequency of Indexing/Updates': 'update_frequency',
    'Action': 'delete',
    'Audit Hierarchy (Matches hierarchy in spreedsheet - Yes / No) - SDE prod': 'audit_hierarchy',
    'Audit URL - SDE prod': 'audit_url',
    'Audit Mapping - SDE prod': 'audit_mapping',
    'Audit Label - SDE prod': 'audit_label',
    'Audit Query - SDE prod': 'audit_query',
    'Audit Duplicate Results - SDE prod': 'audit_duplicate_results',
    'Audit Metrics': 'audit_metrics',
    'Cleaning Assigned To:': 'cleaning_assigned_to',
    'notes': 'notes',
}

# %%
# we don't need Collection Title or Migrated? because they have too little information

# %%
# check whether we need the Sinequa Config Actual column
df.query('~`Sinequa Config Actual`.isnull() & `Sinequa Config Actual` != `Sinequa Config Guess`')

# turns out we don't
# Out:
# Empty DataFrame
# Columns: [Collection Title, Migrated?, Name of Resource, Sinequa Config Guess, Sinequa Config Actual, Connector Type, Assignee, URL_original, URL_sinequa, turned_on, Division, Source, TreeRoot, Indexing instructions, Notes, Audit Notes - SDE prod, Frequency of Indexing/Updates, What Does it Contain?, Action, Audit Hierarchy (Matches hierarchy in spreedsheet - Yes / No) - SDE prod, Audit URL - SDE prod, Audit Mapping - SDE prod, Audit Label - SDE prod, Audit Query - SDE prod, Audit Duplicate Results - SDE prod, Cleaning Assigned To:, Cleaning Finished? (Yes/No/See Sheets), Clean-up Changes/Comments by Cleaner, Audit Comment, Audit Metrics, Audit Hierarchy (Matches hierarchy in spreedsheet - Yes / No) - SDE test, Audit URL - SDE test, Audit Mapping - SDE test, Audit Label - SDE test, Audit Notes - SDE test, Audit Query - SDE test, Audit Duplicate Results - SDE test, Title, Clean Up Results, Description, Connector, Title QC, Title href QC, Preview QC, Metadata QC, Unwanted Docs QC, DynamicUrlList, UrlStayInside, UrlLinkExcluded, UrlDownloadExcluded, UrlFollowExcluded, UrlIndexExcluded, UrlIndexIncluded, IncludedExtensions, ExcludedExtensions, ExcludedFilenames, Cleaned]
# Index: []
#
# [0 rows x 57 columns]

# %%
# fill null configs with empty string for ingesting
df['Sinequa Config Guess'].fillna('', inplace=True)

# %%
# do we need connector type? guess not
df['Connector Type'].value_counts()
# Out:
# crawler2    7
# Name: Connector Type, dtype: int64

# %%
# merge url columns
df["URL_original"].fillna(df["URL_sinequa"], inplace=True)
df["URL_original"].fillna('', inplace=True)

# %%
# handle column turned_on
df.turned_on = df.turned_on.fillna(False)
df.turned_on = df.turned_on.replace(1.0, True)
df.turned_on = df.turned_on.replace(0.0, False)
df.turned_on.value_counts()
# Out:
# False    159
# True     122
# Name: turned_on, dtype: int64

# %%
# handle division
df['Division'] = df['Division'].replace('Planetary', 'Planetary Science')

# replace division names with ids
division_mapper = {
    "Planetary Science": 5,
    "Earth Science": 3,
    "Biological and Physical Sciences": 2,
    "Heliophysics": 4,
    "Astrophysics": 1,
}
df['Division'].replace(division_mapper, inplace=True)

# %%
# source mapper

source_mapper = {
    "Only in original": 1,
    "both": 2,
    "Only in Sinequa": 3,
}
df['Source'].replace(source_mapper, inplace=True)
df['Source'].value_counts()
# Out:
# 2    143
# 1     81
# 3     57
# Name: Source, dtype: int64

# %%
# combine all instruction columns

def generate_notes(row):
    note_fields = [
        'Indexing instructions',
        'Notes',
        'Audit Notes - SDE prod',
        'What Does it Contain?',
        'Audit Comment',
        'Clean-up Changes/Comments by Cleaner',
    ]
    notes = []
    for field in note_fields:
        if not pd.isnull(row[field]):
            notes.append(f'{field}: {row[field]}')
    return '\n\n'.join(notes)

df['notes'] = df.apply(lambda row: generate_notes(row), axis=1)

# %%
df[['Name of Resource', 'notes']]
# Out:
#                 Name of Resource  \
# 0                  NAVO Registry
# 1          Coordinate Calculator
# 2          Extinction Calculator
# 3            Velocity Calculator
# 4    High Level Science Products
# ..                           ...
# 276      PDS Subset Tool Website
# 277     PDS Users Guides Website
# 278       PDS USGS Pilot Website
# 279      PDS Web Chronos Website
# 280             TASKBOOK Website
#
#                                                  notes
# 0    Indexing instructions: Use custom connector bu...
# 1    Indexing instructions: Index just this page\n\...
# 2    Indexing instructions: Index just this page\n\...
# 3    Indexing instructions: Index just this page\n\...
# 4    Indexing instructions: Index only the content ...
# ..                                                 ...
# 276
# 277
# 278
# 279
# 280
#
# [281 rows x 2 columns]

# %%
df['Frequency of Indexing/Updates'].replace({'Once a month': 'Monthly', 'Once week': 'Weekly'}, inplace=True)
df['Frequency of Indexing/Updates'].fillna('Weekly', inplace=True)
df['Frequency of Indexing/Updates'].value_counts()
# Out:
# Monthly     182
# Weekly       87
# Daily         8
# Biweekly      4
# Name: Frequency of Indexing/Updates, dtype: int64

# %%
# frequency mapper

frequency_mapper = {
    "Daily": 1,
    "Weekly": 2,
    "Biweekly": 3,
    "Monthly": 4
}
df['Frequency of Indexing/Updates'].replace(frequency_mapper, inplace=True)
df['Frequency of Indexing/Updates'].value_counts()
# Out:
# 4    182
# 2     87
# 1      8
# 3      4
# Name: Frequency of Indexing/Updates, dtype: int64

# %%
df['Action'].fillna(False, inplace=True)
df['Action'] = df['Action'].replace('Delete', True)
df['Action'].value_counts()
# Out:
# False    251
# True      30
# Name: Action, dtype: int64

# %%
df['Cleaning Assigned To:'].value_counts()
# Out:
# Shravan                                  34
# Nothing needed. Deleted as requested.    28
# Carson                                   23
# Nothing needed. Looks good.              23
# Ashish                                   19
# Dr. Li                                   16
# Looks good. Nothing needed.               1
# Looks good. Nothing needed                1
# Nothing needed. Looks good                1
# Name: Cleaning Assigned To:, dtype: int64

# %%
# ignoring this one because we're just starting the cleaning, so it couldn't possibly have been finished.
df['Cleaning Finished? (Yes/No/See Sheets)'].value_counts()
# Out:
# Yes                  55
# ignore .xml, .ico     1
# Name: Cleaning Finished? (Yes/No/See Sheets), dtype: int64

# %%
df['Clean-up Changes/Comments by Cleaner'].value_counts()
# Out:
# - Changed to JSON connector.\n- developed a function plugin to translate values\n- created a new HTML template                                                                                                                                  5
# No change                                                                                                                                                                                                                                       3
# No Change                                                                                                                                                                                                                                       2
# -Added conversion plan SMD_Advnaced_Docs                                                                                                                                                                                                        2
# Ok, so I initially created a webcrawler for this called PDS_Data_Dictionary_Search, however, I think it is totally insufficient. There seems to be some fancy .js that drives the site, will need to better figure out how to bring it in.      1
# Conversion plan added SMD_Advanced_Docs                                                                                                                                                                                                         1
# - Converted to a JSON connector. dataset webpages indexed for each catalog item.                                                                                                                                                                1
# - the existing Amamzon S3 credentials do not work. Do we need to get new creds or index the website?                                                                                                                                            1
# - what does ComposeEarthSciencePath plugin in the mapping do? not present in the plugins. Do we need this?                                                                                                                                      1
# - Changed to JSON connector.\n- developed a function plugin to translate values\n- created a new HTML template\n- unable to find usage from and to metadata                                                                                     1
# -Added conversion plan SMD_Advanced_docs\n- changed the connector type from hyperindex to webcrawler                                                                                                                                            1
# I turned this back on and reindexed. However I don't trust it. It has the exact same number of documents, 110, as the naif tutorials connector. In fact, I don't trust any of these naif connectors.                                            1
# - created a new template for test\n- This has a JSOn url.\n                                                                                                                                                                                     1
# -Added conversion plan SMD_Advanced_Docs\n- title gets indexed as per the page title. Do we need a common title across all records?                                                                                                             1
# - Added conversion plan SMD_Advanced_Docs to handle ppt and office docs\n- Switched off Stay inside URL and Stay inside referer URL                                                                                                             1
# - added conversion plan. \n- switched off "stay inside URL"                                                                                                                                                                                     1
# -Added conversion plan                                                                                                                                                                                                                          1
# - Do we index all links inside the datasets as well? Then we might need to switch off stay inside url and referer url                                                                                                                           1
# Added conversion plan                                                                                                                                                                                                                           1
# -Added conversion plan SMD_Advanced_Docs\n- excluded filename with rss                                                                                                                                                                          1
# -Added conversion plan SMD_Advanced_Docs\n- Do we need to index the actual code of the software?                                                                                                                                                1
# -Added conversion plan SMD_Advanced_Docs\n- Changed the URL from http -> https                                                                                                                                                                  1
# - switched off stay inside url\n-added conversion plan                                                                                                                                                                                          1
# -added conversion plan\n-excluded js\n- switched off stay inside url and referer url. Since all the datasets need to be indexed , it need to go outside the root url\n- added */data/* url for linking\n- excluded *.ps from url for linking    1
# - switched off stay inside url                                                                                                                                                                                                                  1
# - split this in 2 collections:\n- SPASE_Website -> scrapes JSON URLs and writes to a custom file\n-SPASE_JSON -> indexes the JSON URLs from the custom file                                                                                     1
# Name: Clean-up Changes/Comments by Cleaner, dtype: int64

# %%
df['Audit Metrics'].value_counts()
# Out:
# Good       68
# Update     32
# Missing    13
# Name: Audit Metrics, dtype: int64

# %%
# decided not to bring in information about audit in test
# 1. we're going to reindex anyway
# 2. there's not a lot of information here anyway

print(df['Audit Hierarchy (Matches hierarchy in spreedsheet - Yes / No) - SDE test'].value_counts())
print(df['Audit URL - SDE test'].value_counts())
print(df['Audit Mapping - SDE test'].value_counts())
print(df['Audit Label - SDE test'].value_counts())
print(df['Audit Notes - SDE test'].value_counts())
print(df['Audit Query - SDE test'].value_counts())
print(df['Audit Duplicate Results - SDE test'].value_counts())
# Out:
# Yes    9
# No     8
# Name: Audit Hierarchy (Matches hierarchy in spreedsheet - Yes / No) - SDE test, dtype: int64
# No                                10
# Yes                                6
# Yes (sort of, content is same)     1
# Name: Audit URL - SDE test, dtype: int64
# Yes    12
# No      5
# Name: Audit Mapping - SDE test, dtype: int64
# No     9
# Yes    7
# ?      1
# Name: Audit Label - SDE test, dtype: int64
# with query "LEARN TO USE EARTH OBSERVATIONS", top return is xml file https://sservi.nasa.gov/articles/tag/asteroid-grand-challenge/feed/; with query "We offer in-person and online trainings for beginners and advanced practitioners alike, across a breadth of topics including disaster management, ecological forecasting, agriculture, public health, and air quality and water resources management", 7 duplidate pages are found, which are all correct    1
# from "Science Knowledge Sources", there is no docs under "Earth Science Airborne Campaigns" label, only docs under  "Earth Science Suborbital Campaigns". Within it, ACEPOL page is generated, which is one of CASEI campaign. ACEPOL landing page in IMPACT cannot be found (probably not indexed?). This observation applies also to deployment, platform, and instrument.                                                                                       1
# from "Science Knowledge Sources", there is no docs under "Earth Science Airborne Deployments" label, only docs under  "Earth Science Suborbital Deployments". Individual pages are empty (no info)                                                                                                                                                                                                                                                                 1
# from "Science Knowledge Sources", there is no docs under "Earth Science Airborne Instruments" label, only docs under  "Earth Science Suborbital Instruments". And returned pages are empty (no info)                                                                                                                                                                                                                                                               1
# from "Science Knowledge Sources", there is no docs under "Earth Science Airborne Platforms" label, only docs under  "Earth Science Suborbital Platforms". The pages with this label are empty (no info), like in instruments and deployment cases                                                                                                                                                                                                                  1
# from "Science Knowledge Sources", there is no docs under "Earth Science Instruments" label, are these indices turned off?                                                                                                                                                                                                                                                                                                                                          1
# from "Science Knowledge Sources", there is no docs under "Earth Science Missions" label, are these indices turned off?                                                                                                                                                                                                                                                                                                                                             1
# from "Science Knowledge Sources", there is no label called "Earth Science Data", but having label "CMR",  spreadsheet info outdated?  landing page https://cmr.earthdata.nasa.gov/search could not be found                                                                                                                                                                                                                                                        1
# There is no label of "NASA Earth Observations Imagery" but "NASA Earth Observations". For docs under this, the tab mapped is "Images" instead of "Data". landing page is https://neo.gsfc.nasa.gov/ but return pages with root of "https://neo.sci.gsfc.nasa.gov/" which are not accessible.                                                                                                                                                                       1
# There is no "Earth Science->Documents > Publications->NTRS Publication Database from empty search returns. The index of this source is turned off or not indexed at all? with search "NTRS", 141 pages returned. They were assigned to many positions of hierarchy, but no one defined in this row. NTRS is not soly for Earth Science                                                                                                                             1
# CSS missing. Screenshot here.                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# No 'Model' tab; Label 'CCMC' instead of Community Coordinated Modeling Center                                                                                                                                                                                                                                                                                                                                                                                      1
# url="http://hapi-server.org/", not https://cdaweb.gsfc.nasa.gov/registry/hdp/hapi/                                                                                                                                                                                                                                                                                                                                                                                 1
# url=https://heliopython.org/projects/ instead of https://heliopython.org/; in tab 'All', not 'Data'                                                                                                                                                                                                                                                                                                                                                                1
# not found in SDE test; instead this source is indexed                                                                                                                                                                                                                                                                                                                                                                                                              1
# Name: Audit Notes - SDE test, dtype: int64
# CASEI                                                                                                                                                                                                                                                                                      4
# SNWG API                                                                                                                                                                                                                                                                                   2
# LEARN TO USE EARTH OBSERVATIONS; "We offer in-person and online trainings for beginners and advanced practitioners alike, across a breadth of topics including disaster management, ecological forecasting, agriculture, public health, and air quality and water resources management"    1
# CMR search The Common Metadata Repository (CMR) is a high-performance, high-quality, continuously evolving metadata system that catalogs Earth Science data and associated service metadata records                                                                                        1
# Earthdata Data Pathfinders                                                                                                                                                                                                                                                                 1
# NEO browse datasets by category                                                                                                                                                                                                                                                            1
# NTRS                                                                                                                                                                                                                                                                                       1
# autoplot                                                                                                                                                                                                                                                                                   1
# Community Coordinated Modeling Center                                                                                                                                                                                                                                                      1
# HAPI                                                                                                                                                                                                                                                                                       1
# Heliophysics Events Knowledgebase                                                                                                                                                                                                                                                          1
# Helioviewer                                                                                                                                                                                                                                                                                1
# pyhc                                                                                                                                                                                                                                                                                       1
# SPASE                                                                                                                                                                                                                                                                                      1
# spedas                                                                                                                                                                                                                                                                                     1
# Name: Audit Query - SDE test, dtype: int64
# No                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             9
# Yes (not exactly the same) (https://appliedsciences.nasa.gov/join-mission/training?title=&program_area=All&languages=All&source=All&page=2; https://appliedsciences.nasa.gov/join-mission/training?title=&program_area=All&languages=All&source=All&page=8, https://appliedsciences.nasa.gov/join-mission/training?title=&program_area=All&languages=All&source=All&page=12; and more with similar pattern and have same content as in landing page https://appliedsciences.nasa.gov/join-mission/training)    1
# return pages not accessible                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Name: Audit Duplicate Results - SDE test, dtype: int64

# %%
# useless
df['Title'].value_counts()
# Out:
# Series([], Name: Title, dtype: int64)

# %%
# useless
df['Clean Up Results'].value_counts()
# Out:
# Crawler is successfully geting the paginated results from all planets. We added ignore for .xml and igore for .ico. We updated to use the new treepath. We deleted all content and force reindexed. COME BACK and check that it isn't indexing the search result page itself, just the datapages.    1
# Had been turned off. Turned back on and reindexed.                                                                                                                                                                                                                                                   1
# had been turned off, turned back on. content deleted and reindexed, took less than a minute.                                                                                                                                                                                                         1
# removed images. still need to have longterm fix for titles if desired. wouldn't let me delete content, so I didn't reindex                                                                                                                                                                           1
# top level page is appearing as expected.                                                                                                                                                                                                                                                             1
# Name: Clean Up Results, dtype: int64

# %%
# useless
df['Description'].value_counts()
# Out:
# GCMD - CASEI - A Discovery Catalog of NASA Airborne and Field Campaigns                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     5
# BPS - The LSDA Website -  Life Sciences Data Archive this contains NASA's Human Research Program (HRP) conducts research and develops technologies that allow humans to travel safely and productively in space.                                                                                                                                                                                                                                                                                                                                            3
# A webpage listing PDS software and mission specific software.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               3
# Use the Analyst's Notebook to explore planetary data from NASA Mars and lunar landed missions                                                                                                                                                                                                                                                                                                                                                                                                                                                               2
# Explore NASA's largest raw spacecraft imagery archive                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# Links to data about Mercury                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Information about the Messenger mission                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# PLANETARY - Collision Induced Absorption Model - Planetary Data Systems Atmospheres Collision Induced Absorption Model                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# PLANETARY - Recently Archived Volumes - Planetary Data Systems Atmospheres Recently Archived Volumes                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# BPS - Task Book - Task Book: Biological & Physical Sciences Division and Human Research Program is an online database of research projects supported by the Space Biology and Physical Sciences research areas within the Biological & Physical Sciences (BPS) Division of NASA's Science Mission Directorate, and the Human Research Program in NASA's Human Exploration and Operations (HEO) Mission Directorate. Research projects within the Translational Research Institute for Space Health (TRISH) are included, beginning with FY2017 projects.    1
# Name: Description, Length: 187, dtype: int64

# %%
# bring this in from the sinequa config
df['Connector'].value_counts()
# Out:
# crawler2      174
# json            4
# generic         1
# hyperindex      1
# Name: Connector, dtype: int64

# %%
# QC cols are basically useless

print(df['Title QC'].value_counts())
print(df['Title href QC'].value_counts())
print(df['Preview QC'].value_counts())
print(df['Metadata QC'].value_counts())
print(df['Unwanted Docs QC'].value_counts())
# Out:
# Many pages display the word Data, which is what shows on the tab, instead of the actual title    1
# Name: Title QC, dtype: int64
# ok    1
# Name: Title href QC, dtype: int64
# Preview was broken. Possibly still being generated    1
# ok                                                    1
# Name: Preview QC, dtype: int64
# ok    1
# Name: Metadata QC, dtype: int64
# some images were being brought in    1
# Name: Unwanted Docs QC, dtype: int64

# %%
# we can bring these in from the sinequa configs 
# skip for now

print(df['DynamicUrlList'].value_counts())
print(df['UrlStayInside'].value_counts())
print(df['UrlLinkExcluded'].value_counts())
print(df['UrlDownloadExcluded'].value_counts())
print(df['UrlFollowExcluded'].value_counts())
print(df['UrlIndexExcluded'].value_counts())
print(df['UrlIndexIncluded'].value_counts())
print(df['IncludedExtensions'].value_counts())
print(df['ExcludedExtensions'].value_counts())
print(df['ExcludedFilenames'].value_counts())
# Out:
# SMD_GENELAB_DYNAMIC_URL_LIST                 1
# SMD_GENELAB_PUBLICATIONS_DYNAMIC_URL_LIST    1
# SMD_TASKBOOK_DYNAMIC_URL_LIST                1
# Name: DynamicUrlList, dtype: int64
# 1.0    190
# 0.0      7
# Name: UrlStayInside, dtype: int64
# */rss/*                                                                                   2
# https://pds-imaging.jpl.nasa.gov/data/*                                                   1
# *download*                                                                                1
# ['https://neo.sci.gsfc.nasa.gov/archive/*', 'https://neo.sci.gsfc.nasa.gov/servlet/*']    1
# ['http://www.ncbi.nlm.nih.gov/*', 'https://taskbook.nasaprs.com/tbp/spaceline.cfm']       1
# Name: UrlLinkExcluded, dtype: int64
# */rss/*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            2
# https://pds-imaging.jpl.nasa.gov/data/*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# *download*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# https://spedas.org/*json*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# ['https://github.com/nasa/GeneLab-sampleProcessing*history*', 'https://github.com/nasa/GeneLab-sampleProcessing*commits*', 'https://github.com/nasa/GeneLab-sampleProcessing*blame*', 'https://github.com/nasa/GeneLab-sampleProcessing*issues*', 'https://github.com/nasa/GeneLab-sampleProcessing*pulls*', 'https://github.com/nasa/GeneLab-sampleProcessing*actions*', 'https://github.com/nasa/GeneLab-sampleProcessing*projects*', 'https://github.com/nasa/GeneLab-sampleProcessing*security*', 'https://github.com/nasa/GeneLab-sampleProcessing*pulse*']                                                                                                                                                                                                                                                                   1
# ['https://github.com/nasa/GeneLab-Training*history*', 'https://github.com/nasa/GeneLab-Training*commits*', 'https://github.com/nasa/GeneLab-Training*blame*', 'https://github.com/nasa/GeneLab-Training*issues*', 'https://github.com/nasa/GeneLab-Training*pulls*', 'https://github.com/nasa/GeneLab-Training*actions*', 'https://github.com/nasa/GeneLab-Training*projects*', 'https://github.com/nasa/GeneLab-Training*security*', 'https://github.com/nasa/GeneLab-Training*pulse*', 'https://github.com/nasa/GeneLab-Training/search*', 'https://github.com/nasa/GeneLab-Training/find*', 'https://github.com/nasa/GeneLab-Training/community*', 'https://github.com/nasa/GeneLab-Training/network*', 'https://github.com/nasa/GeneLab-Training/graphs*', 'https://github.com/nasa/GeneLab-Training/graphs/contributors*']    1
# ['https://search-stage.nasa.gov/explore/headers', 'https://nlsp.nasa.gov/static/lsdapub/lsdapub.css']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# ['http://www.ncbi.nlm.nih.gov/*', 'https://taskbook.nasaprs.com/tbp/spaceline.cfm']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# Name: UrlDownloadExcluded, dtype: int64
# */rss/*                                                                                                  2
# ['https://search-stage.nasa.gov/explore/headers', 'https://nlsp.nasa.gov/static/lsdapub/lsdapub.css']    2
# https://pds-imaging.jpl.nasa.gov/data/*                                                                  1
# *download*                                                                                               1
# ['http://www.ncbi.nlm.nih.gov/*', 'https://taskbook.nasaprs.com/tbp/spaceline.cfm']                      1
# Name: UrlFollowExcluded, dtype: int64
# ['*.png', '*.ico', '*.jpg']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              2
# ['https://search-stage.nasa.gov/explore/headers', 'https://nlsp.nasa.gov/static/lsdapub/lsdapub.css']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2
# ['*.f', '*.dat', '*.rss', '*.xml']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# ['*.gif*', '*.ico']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# ['https://genelab-data.ndc.nasa.gov/*', 'https://genelab.nasa.gov/*', 'https://github.com/nasa/*', 'https://www.speedtest.net/*', 'https://support.apple.com/*', 'https://www.youtube.com/*', 'https://www.javascript.com/*', 'https://galaxy.genelab.nasa.gov/*', 'https://www.usa.gov/*', 'https://bsapubs.onlinelibrary.wiley.com/*', 'https://www.nasa.gov/*', 'https://lsda.jsc.nasa.gov/*', 'https://science.nasa.gov/*', 'https://lsda.jsc.nasa.gov/*', 'https://www.issnationallab.org/*', 'https://intern.nasa.gov/*', 'https://gl4hsapp.com/*', 'https://www.researchgate.net/*', 'https://astrobiology.botany.wisc.edu/*', 'https://support.google.com/*', 'https://support.mozilla.org/*', 'https://srag.jsc.nasa.gov/*', 'https://visualization.genelab.nasa.gov/*', 'https://nspires.nasaprs.com/*', 'https://npp.usra.edu/*', 'https://www.djangoproject.com/*', 'https://ti.arc.nasa.gov/*', 'https://gilroy-qlik.botany.wisc.edu/*']    1
# ['https://github.com/nasa/GeneLab-Training*history*', 'https://github.com/nasa/GeneLab-Training*commits*', 'https://github.com/nasa/GeneLab-Training*blame*', 'https://github.com/nasa/GeneLab-Training*issues*', 'https://github.com/nasa/GeneLab-Training*pulls*', 'https://github.com/nasa/GeneLab-Training*actions*', 'https://github.com/nasa/GeneLab-Training*projects*', 'https://github.com/nasa/GeneLab-Training*security*', 'https://github.com/nasa/GeneLab-Training*pulse*', 'https://github.com/nasa/GeneLab-Training/search*', 'https://github.com/nasa/GeneLab-Training/find*', 'https://github.com/nasa/GeneLab-Training/community*', 'https://github.com/nasa/GeneLab-Training/network*', 'https://github.com/nasa/GeneLab-Training/graphs*', 'https://github.com/nasa/GeneLab-Training/graphs/contributors*']                                                                                                                          1
# ['https://github.com/nasa/GeneLab-sampleProcessing*history*', 'https://github.com/nasa/GeneLab-sampleProcessing*commits*', 'https://github.com/nasa/GeneLab-sampleProcessing*blame*', 'https://github.com/nasa/GeneLab-sampleProcessing*issues*', 'https://github.com/nasa/GeneLab-sampleProcessing*pulls*', 'https://github.com/nasa/GeneLab-sampleProcessing*actions*', 'https://github.com/nasa/GeneLab-sampleProcessing*projects*', 'https://github.com/nasa/GeneLab-sampleProcessing*security*', 'https://github.com/nasa/GeneLab-sampleProcessing*pulse*']                                                                                                                                                                                                                                                                                                                                                                                         1
# https://spedas.org/*json*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# ['https://www.lmsal.com/hek/her?cmd=export-voevent*', 'https://www.lmsal.com/hek/her?cmd=home*', '*.pro']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# ['https://photojournal.jpl.nasa.gov/*rss*', 'https://photojournal.jpl.nasa.gov/*favorites*']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# */rss/*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# ['https://*.f', 'http://*.f']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# ['*/rss/*', '*old_versions*', '*gallery*', '*index*', '*.gif', '*.png', '*.jpg', '*.jpeg']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# ['*.jpg', '*.png', '*.ico']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# ['http://*/feed/*', 'https://*/feed/*']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# *download*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# ['https://mars.nasa.gov/*/videos/*', 'https://mars.nasa.gov/*/podcast/*', 'https://mars.nasa.gov/*usdz']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# *.gif*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# ['*wp-json*', '*feed*', '*.ico', '*manifest.xml*', '*rsd']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# https://pds-imaging.jpl.nasa.gov/data/*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# https://pds-atmospheres.nmsu.edu/*rss*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Name: UrlIndexExcluded, dtype: int64
# ['https://nlsp.nasa.gov/view/lsdapub/lsda_document/*', 'https://nlsp.nasa.gov/view/lsdapub/lsda_experiment/*', 'https://nlsp.nasa.gov/view/lsdapub/lsda_subject/*', 'https://nlsp.nasa.gov/view/lsdapub/lsda_biospecimen/*', 'https://nlsp.nasa.gov/view/lsdapub/lsda_dataset/*', 'https://nlsp.nasa.gov/view/lsdapub/lsda_hardware/*', 'https://nlsp.nasa.gov/view/lsdapub/lsda_image/*', 'https://nlsp.nasa.gov/view/lsdapub/lsda_mission/*']    3
# https://an.rsl.wustl.edu/                                                                                                                                                                                                                                                                                                                                                                                                                          2
# https://isis.astrogeology.usgs.gov/7.0.0/index.html                                                                                                                                                                                                                                                                                                                                                                                                1
# https://pds.nasa.gov/datastandards/training/                                                                                                                                                                                                                                                                                                                                                                                                       1
# https://nasa-pds.github.io/mi-label/                                                                                                                                                                                                                                                                                                                                                                                                               1
# https://naif.jpl.nasa.gov/naif/utilities.html                                                                                                                                                                                                                                                                                                                                                                                                      1
# https://naif.jpl.nasa.gov/naif/toolkit.html                                                                                                                                                                                                                                                                                                                                                                                                        1
# https://naif.jpl.nasa.gov/naif/cosmographia_components.html                                                                                                                                                                                                                                                                                                                                                                                        1
# http://autoplot.org/                                                                                                                                                                                                                                                                                                                                                                                                                               1
# ['https://ccmc.gsfc.nasa.gov/tools/', 'https://ccmc.gsfc.nasa.gov/', 'https://ccmc.gsfc.nasa.gov/models/*']                                                                                                                                                                                                                                                                                                                                        1
# https://spedas.org/blog/                                                                                                                                                                                                                                                                                                                                                                                                                           1
# ['https://github.com/nasa/GeneLab-sampleProcessing/tree/master/SOP_pdfs/*', 'https://github.com/nasa/GeneLab-sampleProcessing', 'https://github.com/nasa/GeneLab-sampleProcessing/blob/master/SOP_pdfs/*']                                                                                                                                                                                                                                         1
# ['https://github.com/nasa/GeneLab-Training', 'https://github.com/nasa/GeneLab-Training/tree/main/GL4U', 'https://github.com/nasa/GeneLab-Training/tree/main/GL4U/RNAseq']                                                                                                                                                                                                                                                                          1
# https://osdr.nasa.gov/*OSD*                                                                                                                                                                                                                                                                                                                                                                                                                        1
# https://atmos.nmsu.edu/data_and_services/atmospheres_data/LADEE/nms_search.html                                                                                                                                                                                                                                                                                                                                                                    1
# https://nasa-pds.github.io/pds4-jparser/                                                                                                                                                                                                                                                                                                                                                                                                           1
# https://atmos.nmsu.edu/data_and_services/atmospheres_data/LADEE/nms_derived_search.html                                                                                                                                                                                                                                                                                                                                                            1
# https://pds-atmospheres.nmsu.edu/data_and_services/atmospheres_data/LADEE/requesting_uvs_2.html                                                                                                                                                                                                                                                                                                                                                    1
# https://astrocloud.wr.usgs.gov/index.php?view=map2                                                                                                                                                                                                                                                                                                                                                                                                 1
# https://atmos.nmsu.edu/data_and_services/atmospheres_data/MAVEN/acc_search.html                                                                                                                                                                                                                                                                                                                                                                    1
# https://atmos.nmsu.edu/data_and_services/atmospheres_data/MAVEN/ngims_search.html                                                                                                                                                                                                                                                                                                                                                                  1
# https://pds-geosciences.wustl.edu/missions/mars_express/omega.htm#OAT                                                                                                                                                                                                                                                                                                                                                                              1
# https://opus.pds-rings.seti.org/opus/                                                                                                                                                                                                                                                                                                                                                                                                              1
# https://pds-imaging.jpl.nasa.gov/software/                                                                                                                                                                                                                                                                                                                                                                                                         1
# https://astrocloud.wr.usgs.gov/index.php?view=pow                                                                                                                                                                                                                                                                                                                                                                                                  1
# https://naif.jpl.nasa.gov/cgi-bin/subsetds.pl?dataset=clem1-l-spice-6-v1.0/clsp_1000                                                                                                                                                                                                                                                                                                                                                               1
# https://pilot.wr.usgs.gov/                                                                                                                                                                                                                                                                                                                                                                                                                         1
# https://naif.jpl.nasa.gov/cgi-bin/chronos.pl?setup=chronos                                                                                                                                                                                                                                                                                                                                                                                         1
# https://nasa-pds.github.io/pds4-information-model/model-lddtool/index.html                                                                                                                                                                                                                                                                                                                                                                         1
# https://pds.nasa.gov/tools/tool-registry/                                                                                                                                                                                                                                                                                                                                                                                                          1
# https://jmars.asu.edu/                                                                                                                                                                                                                                                                                                                                                                                                                             1
# https://pds.nasa.gov/datasearch/subscription-service/top.cfm                                                                                                                                                                                                                                                                                                                                                                                       1
# ['https://hitran.org/', 'https://hitran.org/about/']                                                                                                                                                                                                                                                                                                                                                                                               1
# https://trek.nasa.gov/#                                                                                                                                                                                                                                                                                                                                                                                                                            1
# https://eyes.nasa.gov/                                                                                                                                                                                                                                                                                                                                                                                                                             1
# https://pds-rings.seti.org/tools/                                                                                                                                                                                                                                                                                                                                                                                                                  1
# https://pds-rings.seti.org/toolkits/                                                                                                                                                                                                                                                                                                                                                                                                               1
# https://pds-ppi.igpp.ucla.edu/search/view/?f=yes&id=*                                                                                                                                                                                                                                                                                                                                                                                              1
# https://pds-ppi.igpp.ucla.edu/search/?e=*                                                                                                                                                                                                                                                                                                                                                                                                          1
# https://pds-ppi.igpp.ucla.edu/software/index.jsp                                                                                                                                                                                                                                                                                                                                                                                                   1
# https://pds-imaging.jpl.nasa.gov/atlas/info.html                                                                                                                                                                                                                                                                                                                                                                                                   1
# https://pds-atmospheres.nmsu.edu/PDS/OAL/                                                                                                                                                                                                                                                                                                                                                                                                          1
# https://www.usgs.gov/software/integrated-software-imagers-and-spectrometers-isis                                                                                                                                                                                                                                                                                                                                                                   1
# *.TXT                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# https://pds-smallbodies.astro.umd.edu/tools/software.shtml                                                                                                                                                                                                                                                                                                                                                                                         1
# https://sbn.psi.edu/pds/sbib/                                                                                                                                                                                                                                                                                                                                                                                                                      1
# https://pds-smallbodies.astro.umd.edu/data_sb/by_mission.shtml                                                                                                                                                                                                                                                                                                                                                                                     1
# https://pds-geosciences.wustl.edu/tools/default.htm                                                                                                                                                                                                                                                                                                                                                                                                1
# https://va.rsl.wustl.edu/                                                                                                                                                                                                                                                                                                                                                                                                                          1
# http://grspds2.lpl.arizona.edu/                                                                                                                                                                                                                                                                                                                                                                                                                    1
# https://pds-speclib.rsl.wustl.edu/                                                                                                                                                                                                                                                                                                                                                                                                                 1
# https://ode.rsl.wustl.edu/mars/coordinatedobservationsearch.aspx                                                                                                                                                                                                                                                                                                                                                                                   1
# https://ode.rsl.wustl.edu/mars/index.aspx                                                                                                                                                                                                                                                                                                                                                                                                          1
# https://ode.rsl.wustl.edu/moon/index.aspx                                                                                                                                                                                                                                                                                                                                                                                                          1
# https://oderest.rsl.wustl.edu/GDSWeb/GDSDLRERDR.html                                                                                                                                                                                                                                                                                                                                                                                               1
# https://ode.rsl.wustl.edu/mercury/index.aspx                                                                                                                                                                                                                                                                                                                                                                                                       1
# https://ode.rsl.wustl.edu/Venus/index.aspx                                                                                                                                                                                                                                                                                                                                                                                                         1
# https://taskbook.nasaprs.com/tbp/index.cfm?action=public_query_taskbook_content*                                                                                                                                                                                                                                                                                                                                                                   1
# Name: UrlIndexIncluded, dtype: int64
# htm;html                         164
# htm;html;txt;rtf                   1
# htm;html;pdf;txt;doc;docx;rtf      1
# Name: IncludedExtensions, dtype: int64
# txt;act;gz    1
# json;txt      1
# Name: ExcludedExtensions, dtype: int64
# *index.html;*.xml    4
# *.jy                 1
# Name: ExcludedFilenames, dtype: int64

# %%
# useless
df['Cleaned'].value_counts()
# Out:
# Series([], Name: Cleaned, dtype: int64)

# %%
new = df[columns_to_bring_in.keys()].copy()
new.rename(columns=columns_to_bring_in, inplace=True)

# %%
# do a final fillna on text columns
new.url = new.url.fillna('')
new.url = new.url.replace('Use custom connector built by team', '')
new.url = new.url.replace('See notes', '')
new.config_folder = new.config_folder.fillna('')
new['tree_root'].fillna('', inplace=True)
new['audit_hierarchy'].fillna('', inplace=True)
new['audit_url'].fillna('', inplace=True)
new['audit_mapping'].fillna('', inplace=True)
new['audit_label'].fillna('', inplace=True)
new['audit_query'].fillna('', inplace=True)
new['audit_duplicate_results'].fillna('', inplace=True)
new['audit_metrics'].fillna('', inplace=True)
new['cleaning_assigned_to'].fillna('', inplace=True)

# %%
new[~new.url.str.startswith('ht')]
# Out:
#                                                   name  \
# 0                                        NAVO Registry
# 104                        Planetary Data System (PDS)
# 198  PDS API (known as 'Legacy Registry' in the EDP...
# 225                                ASTRO Multi Website
# 235                  Helioviewer Documentation Website
# 236                                 LSDA Website Trial
# 237                                LSDA Website Trial2
# 280                                   TASKBOOK Website
#
#                                config_folder  \
# 0
# 104  PDS_Planetary_Data_System_(PDS)_Website
# 198                       PDS_API_Legacy_All
# 225                      ASTRO_Multi_Website
# 235        Helioviewer_Documentation_Website
# 236                       LSDA_Website_Trial
# 237                      LSDA_Website_Trial2
# 280                         TASKBOOK_Website
#
#                                                    url  turned_on  division  \
# 0                                                           False         1
# 104                                                         False         5
# 198                                                          True         5
# 225  ['https://github.com/adsabs/adsabs-dev-api', '...      False         1
# 235  ['http://www.jhelioviewer.org/', 'http://swhv....      False         4
# 236  ['https://nlsp.nasa.gov/search/?q=all&pagesize...      False         2
# 237  ['https://nlsp.nasa.gov/search/?q=all&pagesize...      False         2
# 280                                                         False         5
#
#      source                                          tree_root  \
# 0         1
# 104       2       Planetary/Data//Planetary Data System (PDS)/
# 198       2  Planetary Science/Data/Planetary Science Data ...
# 225       3                                      Astrophysics/
# 235       3  Heliophysics/Software and Tools/Helioviewer/JH...
# 236       3                   LSDA/Life Sciences Data Archive/
# 237       3                   LSDA/Life Sciences Data Archive/
# 280       3                                           Taskbook
#
#      update_frequency  delete audit_hierarchy audit_url audit_mapping  \
# 0                   1   False              No        No            No
# 104                 1    True
# 198                 1   False              No         ?           Yes
# 225                 2   False
# 235                 2   False
# 236                 2   False
# 237                 2   False
# 280                 2   False
#
#     audit_label                                        audit_query  \
# 0            No  https://sciencediscoveryengine.nasa.gov/app/na...
# 104
# 198          No
# 225
# 235
# 236
# 237
# 280
#
#     audit_duplicate_results audit_metrics cleaning_assigned_to  \
# 0
# 104                                Update               Carson
# 198                                Update              Shravan
# 225
# 235
# 236
# 237
# 280
#
#                                                  notes
# 0    Indexing instructions: Use custom connector bu...
# 104  Indexing instructions: Use custom connector bu...
# 198  Indexing instructions: Use custom connector bu...
# 225
# 235
# 236
# 237
# 280

# %%
# remove multi urls
mask = new.url.apply(lambda row: row.startswith('['))
column_name = 'url'
new.loc[mask, column_name] = ''

# %%
# which ones don't have URLs
new[~new.url.str.startswith('ht')]
# Out:
#                                                   name  \
# 0                                        NAVO Registry
# 104                        Planetary Data System (PDS)
# 198  PDS API (known as 'Legacy Registry' in the EDP...
# 225                                ASTRO Multi Website
# 235                  Helioviewer Documentation Website
# 236                                 LSDA Website Trial
# 237                                LSDA Website Trial2
# 280                                   TASKBOOK Website
#
#                                config_folder url  turned_on  division  source  \
# 0                                                     False         1       1
# 104  PDS_Planetary_Data_System_(PDS)_Website          False         5       2
# 198                       PDS_API_Legacy_All           True         5       2
# 225                      ASTRO_Multi_Website          False         1       3
# 235        Helioviewer_Documentation_Website          False         4       3
# 236                       LSDA_Website_Trial          False         2       3
# 237                      LSDA_Website_Trial2          False         2       3
# 280                         TASKBOOK_Website          False         5       3
#
#                                              tree_root  update_frequency  \
# 0                                                                      1
# 104       Planetary/Data//Planetary Data System (PDS)/                 1
# 198  Planetary Science/Data/Planetary Science Data ...                 1
# 225                                      Astrophysics/                 2
# 235  Heliophysics/Software and Tools/Helioviewer/JH...                 2
# 236                   LSDA/Life Sciences Data Archive/                 2
# 237                   LSDA/Life Sciences Data Archive/                 2
# 280                                           Taskbook                 2
#
#      delete audit_hierarchy audit_url audit_mapping audit_label  \
# 0     False              No        No            No          No
# 104    True
# 198   False              No         ?           Yes          No
# 225   False
# 235   False
# 236   False
# 237   False
# 280   False
#
#                                            audit_query  \
# 0    https://sciencediscoveryengine.nasa.gov/app/na...
# 104
# 198
# 225
# 235
# 236
# 237
# 280
#
#     audit_duplicate_results audit_metrics cleaning_assigned_to  \
# 0
# 104                                Update               Carson
# 198                                Update              Shravan
# 225
# 235
# 236
# 237
# 280
#
#                                                  notes
# 0    Indexing instructions: Use custom connector bu...
# 104  Indexing instructions: Use custom connector bu...
# 198  Indexing instructions: Use custom connector bu...
# 225
# 235
# 236
# 237
# 280

# %%
def create_fixture(row):
    return {
            "model": "sde_collections.collection",
            "fields": {
                "name": row["name"],
                "config_folder": row["config_folder"],
                "url": row["url"],
                "turned_on": row["turned_on"],
                "division": row["division"],
                "source": row["source"],
                "tree_root": row["tree_root"],
                "update_frequency": row["update_frequency"],
                "delete": row["delete"],
                "audit_hierarchy": row["audit_hierarchy"],
                "audit_url": row["audit_url"],
                "audit_mapping": row["audit_mapping"],
                "audit_label": row["audit_label"],
                "audit_query": row["audit_query"],
                "audit_duplicate_results": row["audit_duplicate_results"],
                "audit_metrics": row["audit_metrics"],
                "cleaning_assigned_to": row["cleaning_assigned_to"],
                "notes": row["notes"],
            }
    }

# %%
new['json'] = new.apply(lambda row: create_fixture(row), axis=1)

# %%
with open('../sde_collections/fixtures/collections.json', 'w') as fixturefile:
    fixturefile.write(json.dumps(new.json.to_list()))
